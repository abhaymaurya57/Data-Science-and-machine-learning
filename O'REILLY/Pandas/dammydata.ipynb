# %%
import pandas as pd
import numpy as np

# %%
a=pd.read_csv("ai-medical-chatbot.csv")

# %%
b=a.head(50000)

# %%
c=b.to_csv("ai_mediacal.csv")

# %%
d=pd.read_csv("ai_mediacal.csv")
d
# Out:
#        Unnamed: 0                                        Description  \
# 0               0      Q. What does abutment of the nerve root mean?
# 1               1  Q. What should I do to reduce my weight gained...
# 2               2  Q. I have started to get lots of acne on my fa...
# 3               3  Q. Why do I have uncomfortable feeling between...
# 4               4  Q. My symptoms after intercourse threatns me e...
# ...           ...                                                ...
# 49995       49995         What causes loose stools during pregnancy?
# 49996       49996  What could cause mild itching in left testicul...
# 49997       49997  What causes labor pain during 7th month of pre...
# 49998       49998             How to ascertain the day of ovulation?
# 49999       49999           Is missed period a symptom of pregnancy?
#
#                                                  Patient  \
# 0      Hi doctor,I am just wondering what is abutting...
# ...

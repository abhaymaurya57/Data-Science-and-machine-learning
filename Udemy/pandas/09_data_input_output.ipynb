# %%
import numpy as np
import pandas as pd

# %% [markdown]
# csv
# excel
# html
# sql

# %%
pwd
# Out:
# 'd:\\Abhay\\Data-Science-and-machine-learning\\Udemy\\pandas'

# %%
pd.read_csv('example.csv')
# Out:
#    Unnamed: 0    A    B  C  D
# 0           0  foo  one  x  1
# 1           1  foo  one  y  3
# 2           2  foo  two  x  2
# 3           3  bar  two  y  5
# 4           4  bar  onw  x  4
# 5           5  bar  onw  y  1

# %%
df=pd.read_csv('example.csv')

# %%
df
# Out:
#    Unnamed: 0    A    B  C  D
# 0           0  foo  one  x  1
# 1           1  foo  one  y  3
# 2           2  foo  two  x  2
# 3           3  bar  two  y  5
# 4           4  bar  onw  x  4
# 5           5  bar  onw  y  1

# %%
df.to_csv('09_output',index=False)

# %%
df.to_excel('09_excel.xlsx',index=False)

# %%
pd.read_csv('09_output')
# Out:
#    Unnamed: 0    A    B  C  D
# 0           0  foo  one  x  1
# 1           1  foo  one  y  3
# 2           2  foo  two  x  2
# 3           3  bar  two  y  5
# 4           4  bar  onw  x  4
# 5           5  bar  onw  y  1

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_excel('fake.xlsx')
# Out:
#     S.No. College No.  Roll No.  Enroll No.  Gender     Cat.
# 0     NaN         NaN       NaN         NaN     NaN      NaN
# 1     1.0     23CSE01       NaN         NaN    MALE  GENERAL
# 2     2.0     23CSE02       NaN         NaN  FEMALE      OBC
# 3     3.0     23CSE03       NaN         NaN    MALE      OBC
# 4     4.0     23CSE04       NaN         NaN    MALE      OBC
# 5     5.0     23CSE05       NaN         NaN    MALE  GENERAL
# 6     6.0     23CSE06       NaN         NaN    MALE      OBC
# 7     7.0     23CSE07       NaN         NaN    MALE  GENERAL
# 8     8.0     23CSE08       NaN         NaN    MALE      OBC
# 9     9.0     23CSE09       NaN         NaN  FEMALE  GENERAL
# 10   10.0     23CSE10       NaN         NaN    MALE  GENERAL
# 11   11.0     23CSE11       NaN         NaN    MALE  GENERAL
# 12   12.0     23CSE12       NaN         NaN    MALE      OBC
# 13   13.0     23CSE13       NaN         NaN    MALE       ST
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_excel('fake.xlsx',sheet_name='sheet1')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pd.read_excel('fake.xlsx',sheet_name='sheet1')
#
# File c:\Users\abhay\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# --> 508     data = io.parse(
#     509         sheet_name=sheet_name,
#     510         header=header,
#     511         names=names,
# ...
